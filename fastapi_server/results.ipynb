# %% [markdown]
# # 实验1：比较2卡推理和4卡推理的区别

# %% [markdown]
# - 输入：70条指令
# - 设置：任务生命周期无限（1天）
# - 结果：
#   - 2卡：1183.678
#     - 最快：337
#     - 最慢：1027
#     - 错6个
#   - 4卡：918.738
#     - 最快：225
#     - 最慢：832
#     - 错7个
# - 原因：本质还是更大显存，提供更大kv cache，提高吞吐量
