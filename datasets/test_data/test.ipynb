# %%
a = 'sss'
a =

# %%
with open('./测试脚本.txt', 'r') as f:
    d = f.read()
d = d.split('\n')
for i,s in enumerate(d):
    d[i] = str(f'[{i+1}]')+s
with open('./测试脚本_1.txt', 'w') as f:
    f.write('\n'.join(d))
